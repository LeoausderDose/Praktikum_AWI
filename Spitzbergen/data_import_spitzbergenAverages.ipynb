# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

# %%
# Customize the default plotting style
plt.rcParams['figure.figsize'] = (8, 6)  # Set the default figure size
plt.rcParams['axes.labelsize'] = 14      # Set the default label font size
plt.rcParams['axes.titlesize'] = 16      # Set the default title font size
plt.rcParams['xtick.labelsize'] = 12     # Set the default x-axis tick font size
plt.rcParams['ytick.labelsize'] = 12     # Set the default y-axis tick font size
plt.rcParams['lines.linewidth'] = 2.0    # Set the default line width
plt.rcParams['lines.markersize'] = 8     # Set the default marker size
plt.rcParams['legend.fontsize'] = 12     # Set the default legend font size
plt.rcParams['axes.grid'] = True         # Enable grid lines by default

# Now, all subsequent plots in your script will use these settings

# %%
# df_01_20 = pd.read_csv('data/NYA_cont-meteorology_2011-08_etseq/datasets/NYA_cont_meteorology_2020-01.tab', sep='\t', skiprows= range(22))
# df_02_20 = pd.read_csv('data/NYA_cont-meteorology_2011-08_etseq/datasets/NYA_cont_meteorology_2020-02.tab', sep='\t', skiprows= range(22))
# df_03_20 = pd.read_csv('data/NYA_cont-meteorology_2011-08_etseq/datasets/NYA_cont_meteorology_2020-03.tab', sep='\t', skiprows= range(22))
# df_04_20 = pd.read_csv('data/NYA_cont-meteorology_2011-08_etseq/datasets/NYA_cont_meteorology_2020-04.tab', sep='\t', skiprows= range(22))
# df_05_20 = pd.read_csv('data/NYA_cont-meteorology_2011-08_etseq/datasets/NYA_cont_meteorology_2020-05.tab', sep='\t', skiprows= range(22))
# df_06_20 = pd.read_csv('data/NYA_cont-meteorology_2011-08_etseq/datasets/NYA_cont_meteorology_2020-06.tab', sep='\t', skiprows= range(22))

# Basisverzeichnis für die Daten
data_dir = 'data/NYA_cont-meteorology_2011-08_etseq/datasets/'

# Erstellen Sie eine leere Liste, um DataFrames zu speichern
years = []



# Schleife für die Monate
for year in range(12,23):
    dataframes = []
    for month in range(1, 13):
        # Erzeugen des Dateinamens
        file_name = f'NYA_cont_meteorology_20{year:02d}-{month:02d}.tab'

        # Lesen der CSV-Datei für den aktuellen Monat
        df = pd.read_csv(data_dir + file_name, sep='\t')
        df['Date/Time'] = pd.to_datetime(df['Date/Time'])
        print('Zahlen der NaN-Einträge: '+str(np.sum(np.isnan(df['T2 [°C] (average, Thermometer)']))))
        df.loc[np.isnan(df['T2 [°C] (average, Thermometer)']),'T2 [°C] (average, Thermometer)'] = 0

        # Fügen Sie den DataFrame zur Liste hinzu
        dataframes.append(df)
    years.append(dataframes.copy())

# for month in range(7, 13):
#     # Erzeugen des Dateinamens
#     file_name = f'NYA_cont_meteorology_2019-{month:02d}.tab'
    
#     # Lesen der CSV-Datei für den aktuellen Monat
#     df = pd.read_csv(data_dir + file_name, sep='\t', skiprows=range(22))
#     df['Date/Time'] = pd.to_datetime(df['Date/Time'])
#     print('Zahlen der NaN-Einträge: '+str(np.sum(np.isnan(df['T2 [°C] (average, Thermometer)']))))
#     df.loc[np.isnan(df['T2 [°C] (average, Thermometer)']),'T2 [°C] (average, Thermometer)'] = 0

#     # Fügen Sie den DataFrame zur Liste hinzu
#     dataframes.append(df)



years
# df_12_09['Date/Time'] = pd.to_datetime(df_12_09['Date/Time'])
# NaNEntries = np.sum(np.isnan(df_12_09['T2 [°C] (average, Thermometer)']))
# df_12_09.loc[np.isnan(df_12_09['T2 [°C] (average, Thermometer)']),'T2 [°C] (average, Thermometer)'] = 0
# #print(df_12_09['T2 [°C] (average, Thermometer)'])
# print(np.sum(np.isnan(df_12_09['T2 [°C] (average, Thermometer)'])))
# df_12_09
# Out:
# Zahlen der NaN-Einträge: 5772
# Zahlen der NaN-Einträge: 5653
# Zahlen der NaN-Einträge: 5732
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 28272
# Zahlen der NaN-Einträge: 10937
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 75
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 1967
# Zahlen der NaN-Einträge: 91
# Zahlen der NaN-Einträge: 95
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 212
# Zahlen der NaN-Einträge: 146
# Zahlen der NaN-Einträge: 166
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 67
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 111
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 73
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 62
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 45
# Zahlen der NaN-Einträge: 15
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 963
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 47
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 7
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 711
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 7
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 151
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 14
# Zahlen der NaN-Einträge: 91
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 123
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 137
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 120
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 7
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 126
# Zahlen der NaN-Einträge: 15
# Zahlen der NaN-Einträge: 2579
# Zahlen der NaN-Einträge: 2026
# Zahlen der NaN-Einträge: 2642
# Zahlen der NaN-Einträge: 751
# Zahlen der NaN-Einträge: 139
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 82
# Zahlen der NaN-Einträge: 18
# Zahlen der NaN-Einträge: 30
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 823
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 21
# Zahlen der NaN-Einträge: 2119
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 501
# Zahlen der NaN-Einträge: 3220
# Zahlen der NaN-Einträge: 262
# Zahlen der NaN-Einträge: 2209
# Zahlen der NaN-Einträge: 394
# Zahlen der NaN-Einträge: 2
# Zahlen der NaN-Einträge: 21
# Zahlen der NaN-Einträge: 259
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 1034
# Zahlen der NaN-Einträge: 16
# Zahlen der NaN-Einträge: 787
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 13
# Zahlen der NaN-Einträge: 89
# Zahlen der NaN-Einträge: 5
# Zahlen der NaN-Einträge: 3003
# Zahlen der NaN-Einträge: 22
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 648
# Zahlen der NaN-Einträge: 56
# Zahlen der NaN-Einträge: 0
# Zahlen der NaN-Einträge: 2
# [[                Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-01-01 00:00:00                             -3.6
#   1     2012-01-01 00:01:00                             -3.1
#   2     2012-01-01 00:02:00                             -3.0
#   3     2012-01-01 00:03:00                             -2.8
#   4     2012-01-01 00:04:00                             -2.9
#   ...                   ...                              ...
#   44635 2012-01-31 23:55:00                              NaN
#   44636 2012-01-31 23:56:00                              NaN
#   44637 2012-01-31 23:57:00                              NaN
#   44638 2012-01-31 23:58:00                              NaN
#   44639 2012-01-31 23:59:00                              NaN
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 114.8                               9.1
#   1                                 111.6                              11.4
#   2                                 113.4                              10.0
#   3                                 110.0                              10.2
#   4                                 108.5                              11.2
#   ...                                 ...                               ...
#   44635                             147.7                               1.7
#   44636                             145.8                               2.4
#   44637                             162.4                               2.7
#   44638                             183.6                               4.9
#   44639                             172.5                               2.9
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                -3.9                            115.9
#   1                                -3.5                            113.4
#   2                                -3.3                            117.0
#   3                                -3.1                            109.9
#   4                                -3.1                            108.2
#   ...                               ...                              ...
#   44635                             0.0                            149.5
#   44636                             0.0                            158.6
#   44637                             0.0                            165.4
#   44638                             0.0                            186.9
#   44639                             0.0                            185.2
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  7.3
#   1                                  9.7
#   2                                  8.8
#   3                                  8.8
#   4                                  9.9
#   ...                                ...
#   44635                              1.6
#   44636                              1.5
#   44637                              2.2
#   44638                              4.0
#   44639                              2.8
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           69.5
#   1                                           65.5
#   2                                           63.4
#   3                                           65.6
#   4                                           65.7
#   ...                                          ...
#   44635                                        NaN
#   44636                                        NaN
#   44637                                        NaN
#   44638                                        NaN
#   44639                                        NaN
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             70.0
#   1                                             65.9
#   2                                             63.7
#   3                                             66.1
#   4                                             65.9
#   ...                                            ...
#   44635                                          NaN
#   44636                                          NaN
#   44637                                          NaN
#   44638                                          NaN
#   44639                                          NaN
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1000.19
#   1                                  1000.18
#   2                                  1000.25
#   3                                  1000.24
#   4                                  1000.21
#   ...                                    ...
#   44635                              1011.67
#   44636                              1011.61
#   44637                              1011.64
#   44638                              1011.65
#   44639                              1011.65
#
#   [44640 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-02-01 00:00:00                              NaN
#   1     2012-02-01 00:01:00                              NaN
#   2     2012-02-01 00:02:00                              NaN
#   3     2012-02-01 00:03:00                              NaN
#   4     2012-02-01 00:04:00                              NaN
#   ...                   ...                              ...
#   41755 2012-02-29 23:55:00                             -3.6
#   41756 2012-02-29 23:56:00                             -3.7
#   41757 2012-02-29 23:57:00                             -3.3
#   41758 2012-02-29 23:58:00                             -3.5
#   41759 2012-02-29 23:59:00                             -3.4
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 214.7                               2.2
#   1                                 126.0                               1.5
#   2                                 175.9                               1.6
#   3                                 148.0                               2.4
#   4                                 150.3                               3.4
#   ...                                 ...                               ...
#   41755                             130.1                               6.1
#   41756                             133.9                               6.3
#   41757                             135.0                               6.4
#   41758                             136.7                               6.2
#   41759                             136.2                               6.6
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                 0.0                            243.7
#   1                                 0.0                            131.4
#   2                                 0.0                            172.6
#   3                                 0.0                            157.6
#   4                                 0.0                            153.2
#   ...                               ...                              ...
#   41755                            -4.7                            138.3
#   41756                            -4.9                            137.3
#   41757                            -4.7                            141.9
#   41758                            -4.7                            139.9
#   41759                            -4.6                            138.9
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  1.8
#   1                                  0.5
#   2                                  1.3
#   3                                  1.6
#   4                                  2.7
#   ...                                ...
#   41755                              4.6
#   41756                              4.6
#   41757                              4.8
#   41758                              4.6
#   41759                              5.0
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                            NaN
#   1                                            NaN
#   2                                            NaN
#   3                                            NaN
#   4                                            NaN
#   ...                                          ...
#   41755                                       58.9
#   41756                                       59.8
#   41757                                       58.4
#   41758                                       58.9
#   41759                                       58.2
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                              NaN
#   1                                              NaN
#   2                                              NaN
#   3                                              NaN
#   4                                              NaN
#   ...                                            ...
#   41755                                         59.0
#   41756                                         60.0
#   41757                                         58.7
#   41758                                         59.2
#   41759                                         58.5
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1011.70
#   1                                  1011.67
#   2                                  1011.65
#   3                                  1011.62
#   4                                  1011.55
#   ...                                    ...
#   41755                               988.93
#   41756                               988.93
#   41757                               988.92
#   41758                               988.92
#   41759                               988.92
#
#   [41760 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-03-01 00:00:00                             -3.5
#   1     2012-03-01 00:01:00                             -3.5
#   2     2012-03-01 00:02:00                             -3.2
#   3     2012-03-01 00:03:00                             -3.7
#   4     2012-03-01 00:04:00                             -3.7
#   ...                   ...                              ...
#   44635 2012-03-31 23:55:00                            -15.6
#   44636 2012-03-31 23:56:00                            -15.6
#   44637 2012-03-31 23:57:00                            -15.7
#   44638 2012-03-31 23:58:00                            -15.7
#   44639 2012-03-31 23:59:00                            -15.6
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 134.8                               6.2
#   1                                 132.6                               6.1
#   2                                 132.6                               6.1
#   3                                 135.9                               5.6
#   4                                 136.4                               5.8
#   ...                                 ...                               ...
#   44635                             330.6                               9.6
#   44636                             329.7                              10.0
#   44637                             326.7                               9.8
#   44638                             336.6                              10.0
#   44639                             338.8                              10.0
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                -4.7                            138.7
#   1                                -4.7                            137.0
#   2                                -4.6                            136.6
#   3                                -4.8                            137.1
#   4                                -4.7                            138.4
#   ...                               ...                              ...
#   44635                           -15.6                            331.6
#   44636                           -15.5                            329.0
#   44637                           -15.6                            327.5
#   44638                           -15.6                            334.3
#   44639                           -15.6                            340.4
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  4.7
#   1                                  4.5
#   2                                  4.4
#   3                                  4.2
#   4                                  4.5
#   ...                                ...
#   44635                              8.6
#   44636                              9.6
#   44637                              9.3
#   44638                              9.1
#   44639                              9.0
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           58.4
#   1                                           58.4
#   2                                           57.7
#   3                                           58.7
#   4                                           58.2
#   ...                                          ...
#   44635                                       66.4
#   44636                                       66.8
#   44637                                       66.0
#   44638                                       67.9
#   44639                                       67.7
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             58.6
#   1                                             58.6
#   2                                             57.9
#   3                                             58.9
#   4                                             58.4
#   ...                                            ...
#   44635                                         66.4
#   44636                                         66.9
#   44637                                         66.1
#   44638                                         68.3
#   44639                                         67.9
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                   988.91
#   1                                   988.90
#   2                                   988.88
#   3                                   988.88
#   4                                   988.88
#   ...                                    ...
#   44635                              1000.77
#   44636                              1000.79
#   44637                              1000.80
#   44638                              1000.82
#   44639                              1000.82
#
#   [44640 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-04-01 00:00:00                            -15.6
#   1     2012-04-01 00:01:00                            -15.6
#   2     2012-04-01 00:02:00                            -15.7
#   3     2012-04-01 00:03:00                            -15.8
#   4     2012-04-01 00:04:00                            -15.6
#   ...                   ...                              ...
#   43195 2012-04-30 23:55:00                             -5.4
#   43196 2012-04-30 23:56:00                             -5.4
#   43197 2012-04-30 23:57:00                             -5.5
#   43198 2012-04-30 23:58:00                             -5.5
#   43199 2012-04-30 23:59:00                             -5.8
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 338.3                              10.2
#   1                                 336.1                               9.7
#   2                                 328.7                               9.1
#   3                                 333.2                               8.0
#   4                                 340.3                               8.7
#   ...                                 ...                               ...
#   43195                               NaN                               0.4
#   43196                               NaN                               0.2
#   43197                               NaN                               0.3
#   43198                             203.8                               0.5
#   43199                             233.5                               0.8
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                               -15.6                            337.6
#   1                               -15.5                            337.1
#   2                               -15.6                            327.5
#   3                               -15.7                            328.9
#   4                               -15.5                            338.5
#   ...                               ...                              ...
#   43195                            -5.5                              NaN
#   43196                            -5.5                              NaN
#   43197                            -6.0                            213.0
#   43198                            -6.0                            208.6
#   43199                            -6.3                            228.2
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  9.0
#   1                                  8.3
#   2                                  8.8
#   3                                  7.7
#   4                                  7.9
#   ...                                ...
#   43195                              0.4
#   43196                              0.2
#   43197                              0.5
#   43198                              0.7
#   43199                              0.8
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           67.3
#   1                                           67.5
#   2                                           66.4
#   3                                           64.7
#   4                                           67.0
#   ...                                          ...
#   43195                                       78.6
#   43196                                       78.5
#   43197                                       80.1
#   43198                                       79.9
#   43199                                       80.2
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             67.5
#   1                                             67.7
#   2                                             66.5
#   3                                             64.7
#   4                                             67.1
#   ...                                            ...
#   43195                                         78.9
#   43196                                         79.0
#   43197                                         80.7
#   43198                                         80.5
#   43199                                         80.9
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1000.82
#   1                                  1000.80
#   2                                  1000.79
#   3                                  1000.77
#   4                                  1000.79
#   ...                                    ...
#   43195                              1003.26
#   43196                              1003.27
#   43197                              1003.28
#   43198                              1003.29
#   43199                              1003.28
#
#   [43200 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-05-01 00:00:00                             -5.8
#   1     2012-05-01 00:01:00                             -5.7
#   2     2012-05-01 00:02:00                             -5.7
#   3     2012-05-01 00:03:00                             -5.9
#   4     2012-05-01 00:04:00                             -5.7
#   ...                   ...                              ...
#   44635 2012-05-31 23:55:00                              1.1
#   44636 2012-05-31 23:56:00                              1.1
#   44637 2012-05-31 23:57:00                              1.1
#   44638 2012-05-31 23:58:00                              1.2
#   44639 2012-05-31 23:59:00                              1.3
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 251.9                               0.6
#   1                                 236.2                               0.8
#   2                                 249.9                               0.5
#   3                                   NaN                               0.3
#   4                                   NaN                               0.3
#   ...                                 ...                               ...
#   44635                             308.6                               4.5
#   44636                             307.6                               4.5
#   44637                             305.6                               4.5
#   44638                             302.1                               5.7
#   44639                             297.2                               5.3
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                -6.1                            257.5
#   1                                -5.9                            252.5
#   2                                -5.9                              NaN
#   3                                -6.0                              NaN
#   4                                -6.0                              NaN
#   ...                               ...                              ...
#   44635                             0.0                            307.3
#   44636                             0.0                            306.2
#   44637                             0.0                            307.9
#   44638                             0.0                            306.4
#   44639                             0.0                            302.7
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  0.6
#   1                                  1.0
#   2                                  0.5
#   3                                  0.3
#   4                                  0.3
#   ...                                ...
#   44635                              3.0
#   44636                              3.4
#   44637                              3.4
#   44638                              3.9
#   44639                              3.9
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           78.5
#   1                                           77.2
#   2                                           76.7
#   3                                           76.6
#   4                                           76.9
#   ...                                          ...
#   44635                                        NaN
#   44636                                        NaN
#   44637                                        NaN
#   44638                                        NaN
#   44639                                        NaN
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             78.6
#   1                                             77.3
#   2                                             76.9
#   3                                             76.9
#   4                                             77.1
#   ...                                            ...
#   44635                                          NaN
#   44636                                          NaN
#   44637                                          NaN
#   44638                                          NaN
#   44639                                          NaN
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1003.27
#   1                                  1003.26
#   2                                  1003.24
#   3                                  1003.24
#   4                                  1003.24
#   ...                                    ...
#   44635                              1014.81
#   44636                              1014.81
#   44637                              1014.82
#   44638                              1014.82
#   44639                              1014.82
#
#   [44640 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-06-01 00:00:00                              1.1
#   1     2012-06-01 00:01:00                              1.1
#   2     2012-06-01 00:02:00                              1.3
#   3     2012-06-01 00:03:00                              1.3
#   4     2012-06-01 00:04:00                              1.2
#   ...                   ...                              ...
#   43195 2012-06-30 23:55:00                              5.5
#   43196 2012-06-30 23:56:00                              5.6
#   43197 2012-06-30 23:57:00                              5.6
#   43198 2012-06-30 23:58:00                              5.6
#   43199 2012-06-30 23:59:00                              5.6
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 298.8                               4.4
#   1                                 304.3                               4.5
#   2                                 296.5                               4.9
#   3                                 299.3                               5.0
#   4                                 301.5                               4.6
#   ...                                 ...                               ...
#   43195                              96.9                               1.2
#   43196                              96.7                               1.1
#   43197                              96.5                               1.1
#   43198                              96.0                               1.1
#   43199                             101.3                               1.1
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                 0.0                            303.4
#   1                                 0.0                            306.4
#   2                                 0.0                            301.5
#   3                                 0.0                            299.7
#   4                                 0.0                            301.2
#   ...                               ...                              ...
#   43195                             5.8                             98.0
#   43196                             5.7                             98.7
#   43197                             5.8                             97.8
#   43198                             5.8                            100.3
#   43199                             5.7                            102.0
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  3.5
#   1                                  3.1
#   2                                  3.6
#   3                                  3.7
#   4                                  3.5
#   ...                                ...
#   43195                              1.4
#   43196                              1.2
#   43197                              1.1
#   43198                              1.2
#   43199                              1.2
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                            NaN
#   1                                            NaN
#   2                                            NaN
#   3                                            NaN
#   4                                            NaN
#   ...                                          ...
#   43195                                       66.7
#   43196                                       66.5
#   43197                                       66.1
#   43198                                       66.9
#   43199                                       67.1
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                              NaN
#   1                                              NaN
#   2                                              NaN
#   3                                              NaN
#   4                                              NaN
#   ...                                            ...
#   43195                                         67.1
#   43196                                         66.9
#   43197                                         66.6
#   43198                                         67.5
#   43199                                         67.6
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1014.83
#   1                                  1014.84
#   2                                  1014.84
#   3                                  1014.83
#   4                                  1014.82
#   ...                                    ...
#   43195                              1007.24
#   43196                              1007.26
#   43197                              1007.26
#   43198                              1007.27
#   43199                              1007.27
#
#   [43200 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-07-01 00:00:00                              5.8
#   1     2012-07-01 00:01:00                              5.7
#   2     2012-07-01 00:02:00                              5.8
#   3     2012-07-01 00:03:00                              5.7
#   4     2012-07-01 00:04:00                              5.8
#   ...                   ...                              ...
#   44635 2012-07-31 23:55:00                              3.5
#   44636 2012-07-31 23:56:00                              3.5
#   44637 2012-07-31 23:57:00                              3.6
#   44638 2012-07-31 23:58:00                              3.6
#   44639 2012-07-31 23:59:00                              3.6
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                  98.5                               1.2
#   1                                  97.3                               1.4
#   2                                  99.0                               1.3
#   3                                  98.0                               1.4
#   4                                  98.0                               1.6
#   ...                                 ...                               ...
#   44635                               NaN                               0.4
#   44636                               NaN                               0.3
#   44637                               NaN                               0.3
#   44638                               NaN                               0.2
#   44639                               NaN                               0.3
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                 5.9                            105.5
#   1                                 5.8                            102.3
#   2                                 5.9                            101.7
#   3                                 5.9                            103.2
#   4                                 5.9                             95.3
#   ...                               ...                              ...
#   44635                             3.5                              NaN
#   44636                             3.5                              NaN
#   44637                             3.6                              NaN
#   44638                             3.6                              NaN
#   44639                             3.5                              NaN
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  1.2
#   1                                  1.4
#   2                                  1.4
#   3                                  1.4
#   4                                  1.5
#   ...                                ...
#   44635                              0.3
#   44636                              0.3
#   44637                              0.3
#   44638                              0.3
#   44639                              0.3
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           68.7
#   1                                           68.1
#   2                                           68.1
#   3                                           68.3
#   4                                           68.9
#   ...                                          ...
#   44635                                       93.7
#   44636                                       94.2
#   44637                                       93.9
#   44638                                       93.8
#   44639                                       93.1
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             69.3
#   1                                             68.5
#   2                                             68.6
#   3                                             68.9
#   4                                             69.4
#   ...                                            ...
#   44635                                         94.5
#   44636                                         94.9
#   44637                                         94.7
#   44638                                         94.1
#   44639                                         93.5
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1007.27
#   1                                  1007.27
#   2                                  1007.27
#   3                                  1007.28
#   4                                  1007.28
#   ...                                    ...
#   44635                              1015.32
#   44636                              1015.33
#   44637                              1015.32
#   44638                              1015.31
#   44639                              1015.31
#
#   [44640 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-08-01 00:00:00                              3.7
#   1     2012-08-01 00:01:00                              3.8
#   2     2012-08-01 00:02:00                              3.9
#   3     2012-08-01 00:03:00                              4.0
#   4     2012-08-01 00:04:00                              4.1
#   ...                   ...                              ...
#   44635 2012-08-31 23:55:00                              4.0
#   44636 2012-08-31 23:56:00                              4.0
#   44637 2012-08-31 23:57:00                              4.1
#   44638 2012-08-31 23:58:00                              4.0
#   44639 2012-08-31 23:59:00                              4.3
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                   NaN                               0.3
#   1                                   NaN                               0.3
#   2                                   NaN                               0.2
#   3                                   NaN                               0.2
#   4                                   NaN                               0.3
#   ...                                 ...                               ...
#   44635                             263.3                               4.1
#   44636                             254.6                               3.3
#   44637                             239.4                               3.4
#   44638                             218.0                               3.4
#   44639                             232.2                               7.3
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                 3.6                              NaN
#   1                                 3.7                              NaN
#   2                                 3.9                              NaN
#   3                                 4.1                              NaN
#   4                                 4.1                              NaN
#   ...                               ...                              ...
#   44635                             3.7                            273.7
#   44636                             3.8                            280.6
#   44637                             3.8                            250.4
#   44638                             3.8                            223.3
#   44639                             4.0                            235.2
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  0.3
#   1                                  0.2
#   2                                  0.2
#   3                                  0.1
#   4                                  0.2
#   ...                                ...
#   44635                              3.6
#   44636                              2.4
#   44637                              2.7
#   44638                              2.6
#   44639                              6.0
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           92.5
#   1                                           92.8
#   2                                           91.8
#   3                                           91.8
#   4                                           91.1
#   ...                                          ...
#   44635                                       86.5
#   44636                                       85.1
#   44637                                       85.5
#   44638                                       86.0
#   44639                                       84.4
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             93.3
#   1                                             93.4
#   2                                             92.5
#   3                                             91.9
#   4                                             91.0
#   ...                                            ...
#   44635                                         87.6
#   44636                                         86.1
#   44637                                         86.4
#   44638                                         87.1
#   44639                                         84.8
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1015.30
#   1                                  1015.30
#   2                                  1015.29
#   3                                  1015.28
#   4                                  1015.27
#   ...                                    ...
#   44635                              1000.66
#   44636                              1000.65
#   44637                              1000.65
#   44638                              1000.66
#   44639                              1000.64
#
#   [44640 rows x 10 columns],
#                   Date/Time  T10 [°C] (average, Thermometer)  \
#   0     2012-09-01 00:00:00                              4.5
#   1     2012-09-01 00:01:00                              4.5
#   2     2012-09-01 00:02:00                              4.5
#   3     2012-09-01 00:03:00                              4.5
#   4     2012-09-01 00:04:00                              4.5
#   ...                   ...                              ...
#   43195 2012-09-30 23:55:00                             -0.1
#   43196 2012-09-30 23:56:00                              0.2
#   43197 2012-09-30 23:57:00                              0.4
#   43198 2012-09-30 23:58:00                              0.4
#   43199 2012-09-30 23:59:00                              0.6
#
#          DD10 [deg] (average, Anemometer)  FF10 [m/s] (average, Anemometer)  \
#   0                                 244.4                               5.0
#   1                                 232.4                               5.1
#   2                                 215.3                               4.9
#   3                                 210.7                               2.9
#   4                                 225.4                               1.8
#   ...                                 ...                               ...
#   43195                             147.7                               1.7
#   43196                             160.2                               1.9
#   43197                             169.7                               1.5
#   43198                             187.2                               1.3
#   43199                             191.0                               1.2
#
#          T2 [°C] (average, Thermometer)  DD2 [deg] (average, Anemometer)  \
#   0                                 3.9                            251.1
#   1                                 3.9                            242.8
#   2                                 4.0                            224.3
#   3                                 4.0                            224.1
#   4                                 4.1                            235.9
#   ...                               ...                              ...
#   43195                            -0.7                            163.7
#   43196                            -0.5                            187.5
#   43197                            -0.2                            199.5
#   43198                            -0.5                            192.7
#   43199                            -0.1                            200.1
#
#          FF2 [m/s] (average, Anemometer)  \
#   0                                  4.3
#   1                                  4.3
#   2                                  4.3
#   3                                  2.7
#   4                                  1.6
#   ...                                ...
#   43195                              1.3
#   43196                              1.4
#   43197                              1.7
#   43198                              1.4
#   43199                              1.2
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           82.9
#   1                                           82.5
#   2                                           82.2
#   3                                           81.5
#   4                                           79.9
#   ...                                          ...
#   43195                                       87.0
# ...
#   1     2022-10-01 00:01:00                    11
#   2     2022-10-01 00:02:00                    11
#   3     2022-10-01 00:03:00                    11
#   4     2022-10-01 00:04:00                    11
#   ...                   ...                   ...
#   44635 2022-10-31 23:55:00                    11
#   44636 2022-10-31 23:56:00                    11
#   44637 2022-10-31 23:57:00                    11
#   44638 2022-10-31 23:58:00                    11
#   44639 2022-10-31 23:59:00                    11
#
#          T10 [°C] (average, Thermometer)  DD10 [deg] (average, Anemometer)  \
#   0                                  3.2                               NaN
#   1                                  3.2                               NaN
#   2                                  3.4                               NaN
#   3                                  3.4                               NaN
#   4                                  3.2                               NaN
#   ...                                ...                               ...
#   44635                             -0.7                             140.3
#   44636                             -0.7                             140.0
#   44637                             -0.8                             139.9
#   44638                             -0.8                             129.2
#   44639                             -0.7                             125.8
#
#          FF10 [m/s] (average, Anemometer)  T2 [°C] (average, Thermometer)  \
#   0                                   0.1                             3.1
#   1                                   0.0                             3.1
#   2                                   0.0                             3.1
#   3                                   0.0                             3.1
#   4                                   0.1                             3.0
#   ...                                 ...                             ...
#   44635                               2.2                            -1.2
#   44636                               2.2                            -0.9
#   44637                               2.6                            -1.0
#   44638                               3.2                            -0.9
#   44639                               3.4                            -0.9
#
#          DD2 [deg] (average, Anemometer)  FF2 [m/s] (average, Anemometer)  \
#   0                                  NaN                              0.4
#   1                                  NaN                              0.4
#   2                                  NaN                              0.5
#   3                                202.3                              0.5
#   4                                212.8                              0.7
#   ...                                ...                              ...
#   44635                            144.2                              1.7
#   44636                            143.5                              1.8
#   44637                            143.4                              2.0
#   44638                            134.7                              2.4
#   44639                            125.5                              2.7
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           94.7
#   1                                           94.5
#   2                                           95.1
#   3                                           94.7
#   4                                           94.9
#   ...                                          ...
#   44635                                       75.6
#   44636                                       74.4
#   44637                                       74.1
#   44638                                       73.2
#   44639                                       72.9
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             98.8
#   1                                             98.6
#   2                                             98.2
#   3                                             98.0
#   4                                             97.9
#   ...                                            ...
#   44635                                         78.6
#   44636                                         77.6
#   44637                                         77.8
#   44638                                         77.6
#   44639                                         77.4
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1010.42
#   1                                  1010.42
#   2                                  1010.42
#   3                                  1010.41
#   4                                  1010.42
#   ...                                    ...
#   44635                               999.08
#   44636                               999.08
#   44637                               999.08
#   44638                               999.08
#   44639                               999.08
#
#   [44640 rows x 11 columns],
#                   Date/Time  Elevation [m a.s.l.]  \
#   0     2022-11-01 00:00:00                    11
#   1     2022-11-01 00:01:00                    11
#   2     2022-11-01 00:02:00                    11
#   3     2022-11-01 00:03:00                    11
#   4     2022-11-01 00:04:00                    11
#   ...                   ...                   ...
#   43195 2022-11-30 23:55:00                    11
#   43196 2022-11-30 23:56:00                    11
#   43197 2022-11-30 23:57:00                    11
#   43198 2022-11-30 23:58:00                    11
#   43199 2022-11-30 23:59:00                    11
#
#          T10 [°C] (average, Thermometer)  DD10 [deg] (average, Anemometer)  \
#   0                                 -0.8                             137.9
#   1                                 -0.6                             124.0
#   2                                 -0.6                             128.5
#   3                                 -0.7                             131.4
#   4                                 -0.8                             125.4
#   ...                                ...                               ...
#   43195                              0.2                             123.9
#   43196                              0.2                             111.7
#   43197                              0.2                             101.2
#   43198                              0.3                             129.3
#   43199                              0.3                             133.3
#
#          FF10 [m/s] (average, Anemometer)  T2 [°C] (average, Thermometer)  \
#   0                                   3.1                            -0.9
#   1                                   3.2                            -0.9
#   2                                   2.9                            -0.8
#   3                                   2.5                            -0.9
#   4                                   2.9                            -1.0
#   ...                                 ...                             ...
#   43195                               1.4                             0.3
#   43196                               1.3                             0.3
#   43197                               1.5                             0.3
#   43198                               1.3                             0.2
#   43199                               1.2                             0.2
#
#          DD2 [deg] (average, Anemometer)  FF2 [m/s] (average, Anemometer)  \
#   0                                135.1                              2.4
#   1                                126.5                              2.7
#   2                                131.2                              2.5
#   3                                134.6                              2.2
#   4                                130.3                              1.9
#   ...                                ...                              ...
#   43195                            127.6                              1.2
#   43196                            116.2                              1.1
#   43197                            101.8                              1.2
#   43198                            134.7                              1.0
#   43199                            141.2                              0.9
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           73.5
#   1                                           73.4
#   2                                           73.3
#   3                                           73.2
#   4                                           74.3
#   ...                                          ...
#   43195                                       97.1
#   43196                                       97.1
#   43197                                       97.4
#   43198                                       97.8
#   43199                                       97.8
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                             77.6
#   1                                             77.8
#   2                                             77.3
#   3                                             77.6
#   4                                             78.1
#   ...                                            ...
#   43195                                        100.0
#   43196                                        100.0
#   43197                                        100.0
#   43198                                        100.0
#   43199                                        100.0
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                   999.09
#   1                                   999.10
#   2                                   999.09
#   3                                   999.08
#   4                                   999.08
#   ...                                    ...
#   43195                              1019.02
#   43196                              1019.02
#   43197                              1019.00
#   43198                              1019.04
#   43199                              1019.08
#
#   [43200 rows x 11 columns],
#                   Date/Time  Elevation [m a.s.l.]  \
#   0     2022-12-01 00:00:00                    11
#   1     2022-12-01 00:01:00                    11
#   2     2022-12-01 00:02:00                    11
#   3     2022-12-01 00:03:00                    11
#   4     2022-12-01 00:04:00                    11
#   ...                   ...                   ...
#   44635 2022-12-31 23:55:00                    11
#   44636 2022-12-31 23:56:00                    11
#   44637 2022-12-31 23:57:00                    11
#   44638 2022-12-31 23:58:00                    11
#   44639 2022-12-31 23:59:00                    11
#
#          T10 [°C] (average, Thermometer)  DD10 [deg] (average, Anemometer)  \
#   0                                  0.2                             106.8
#   1                                  0.2                             114.1
#   2                                  0.2                             124.1
#   3                                  0.2                             122.0
#   4                                  0.2                              75.4
#   ...                                ...                               ...
#   44635                              1.8                              84.9
#   44636                              1.5                              83.0
#   44637                              1.5                              80.5
#   44638                              1.5                              83.8
#   44639                              1.7                              83.2
#
#          FF10 [m/s] (average, Anemometer)  T2 [°C] (average, Thermometer)  \
#   0                                   1.7                             0.3
#   1                                   1.8                             0.2
#   2                                   1.1                             0.2
#   3                                   0.7                             0.2
#   4                                   0.8                             0.2
#   ...                                 ...                             ...
#   44635                               9.3                             1.7
#   44636                               8.7                             1.2
#   44637                               8.8                             1.2
#   44638                               9.0                             1.2
#   44639                               8.8                             1.4
#
#          DD2 [deg] (average, Anemometer)  FF2 [m/s] (average, Anemometer)  \
#   0                                108.5                              1.5
#   1                                114.3                              1.7
#   2                                123.0                              0.9
#   3                                  NaN                              0.4
#   4                                 67.9                              0.6
#   ...                                ...                              ...
#   44635                             82.1                              8.5
#   44636                             87.8                              7.3
#   44637                             83.8                              7.4
#   44638                             85.6                              7.4
#   44639                             85.6                              7.8
#
#          RH [%] (at 2 m height, average, redun...)  \
#   0                                           97.2
#   1                                           97.3
#   2                                           97.5
#   3                                           98.3
#   4                                           99.2
#   ...                                          ...
#   44635                                       61.2
#   44636                                       63.8
#   44637                                       65.1
#   44638                                       64.5
#   44639                                       63.6
#
#          RH [%] (at 2 m height, average, redun...).1  \
#   0                                            100.0
#   1                                            100.0
#   2                                            100.0
#   3                                            100.0
#   4                                            100.0
#   ...                                            ...
#   44635                                         64.5
#   44636                                         67.0
#   44637                                         68.7
#   44638                                         68.1
#   44639                                         67.0
#
#          PoPoPoPo [hPa] (average, Barometer)
#   0                                  1019.04
#   1                                  1019.04
#   2                                  1019.09
#   3                                  1019.11
#   4                                  1019.09
#   ...                                    ...
#   44635                               986.58
#   44636                               986.59
#   44637                               986.58
#   44638                               986.58
#   44639                               986.57
#
#   [44640 rows x 11 columns]]]

# %%
len(years)
years[0][0]['T2 [°C] (average, Thermometer)']
# Out:
# 0       -3.9
# 1       -3.5
# 2       -3.3
# 3       -3.1
# 4       -3.1
#         ...
# 44635    0.0
# 44636    0.0
# 44637    0.0
# 44638    0.0
# 44639    0.0
# Name: T2 [°C] (average, Thermometer), Length: 44640, dtype: float64

# %%
tagesgang_grad_mean = []

for i in range(0,12):
    tagesgang_grad = []
    for y in range(len(years)):
                   
        data = years[y][i]['T2 [°C] (average, Thermometer)'] - np.mean(dataframes[i]['T2 [°C] (average, Thermometer)'])

        fft = np.fft.fft(data)
        t = np.arange(len(data))
        freq = np.fft.fftfreq(t.shape[-1], d = 1/(60*24))
        #print(len(data))
        amplitude = 1/ len(data) * np.abs(fft)
        temp_index = np.where(freq == find_nearest(freq, 1))
        tagesgang_grad.append(amplitude[temp_index])

        # plt.plot(freq, amplitude)
        # # print(NaNEntries)
        # plt.xlim(-3,3)
        # plt.ylim(0,1)
    plt.plot(tagesgang_grad, label = str(i))
    tagesgang_grad_mean.append(np.mean(tagesgang_grad))


plt.legend()
tagesgang_grad_mean
# Out:
# [0.12994607035076292,
#  0.07848111747575458,
#  0.15650409016149583,
#  0.37797269211461443,
#  0.29052687081517165,
#  0.23826000785967916,
#  0.31995394671058497,
#  0.35559862198829445,
#  0.23058051252706893,
#  0.07559772113445158,
#  0.10350021352307857,
#  0.07713675501598936]

# %%
month = ['january', 'february', 'march', 'april','may','june', 'july', 'august', 'september', 'october', 'november', 'december']
#plt.plot(np.arange(1,13), tagesgang_grad)
plt.plot(np.arange(1,13), tagesgang_grad_mean, ls = '', marker = 'x', color = 'r')
plt.xticks(np.arange(1,13), month, rotation = 45)

plt.title('Betrag fft parameter Tagesgang')

plt.savefig('FourrierParamAvg.pdf')
